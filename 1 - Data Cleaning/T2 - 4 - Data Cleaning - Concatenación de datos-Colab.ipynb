# %% [markdown]
# # Concatenar y apendizar datasets.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path_red = "/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/wine/winequality-red.csv"
path_white = "/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/wine/winequality-white.csv"

# %%
red_wine = pd.read_csv(path_red, sep = ";")

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_wine = pd.read_csv(path_white, sep = ";")

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ## El ejemplo del vino tinto y el vino blanco

# %% [markdown]
# Dataset Information:
#
# These data are the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wines.
#
# I think that the initial data set had around 30 variables, but for some reason I only have the 13 dimensional version. I had a list of what the 30 or so variables were, but a.) I lost it, and b.), I would not know which 13 variables are included in the set.
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it )
#
# 1. Alcohol
# 2. Malic acid
# 3. Ash
# 4. Alcalinity of ash
# 5. Magnesium
# 6. Total phenols
# 7. Flavanoids
# 8. Nonflavanoid phenols
# 9. Proanthocyanins
# 10. Color intensity
# 11. Hue
# 12. OD280/OD315 of diluted wines
# 13. Proline
#
# In a classification context, this is a well posed problem with "well behaved" class structures. A good data set for first testing of a new classifier, but not very challenging.
#
#
# Attribute Information:
#
# All attributes are continuous
#
# No statistics available, but suggest to standardise variables for certain uses (e.g. for us with classifiers which are NOT scale invariant)
#
# NOTE: 1st attribute is class identifier (1-3)

# %% [markdown]
# ### Veamos algunas características importantes de dichos datasets

# %%
red_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En python, tenemos dos tipos de ejes,
# * axis = 0 denota el eje horizontal
# * axis = 1 denota el eje vertical

# %%
wine_data = pd.concat([red_wine, white_wine], axis = 0)

# %%
wine_data.shape
# Out:
# (6497, 12)

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
# Vamos a unir los siguientes datasets en uno solo

data1 = wine_data.head(10)
data2 = wine_data[300:310]
data3 = wine_data.tail(10)

# %%
# El proceso es el siguiente:

wine_scramble = pd.concat([data1, data2, data3], axis = 0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 300             7.5             0.530         0.06            2.60      0.086
# ...

# %%
# Veamos una redefinicón, tomando un orden distinto en los datasets:

wine_scramble = pd.concat([data2, data3, data1], axis = 0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 300             7.5             0.530         0.06            2.60      0.086
# 301            11.1             0.180         0.48            1.50      0.068
# 302             8.3             0.705         0.12            2.60      0.092
# 303             7.4             0.670         0.12            1.60      0.186
# 304             8.4             0.650         0.60            2.10      0.112
# 305            10.3             0.530         0.48            2.50      0.063
# 306             7.6             0.620         0.32            2.20      0.082
# 307            10.3             0.410         0.42            2.40      0.213
# 308            10.3             0.430         0.44            2.40      0.214
# 309             7.4             0.290         0.38            1.70      0.062
# 4888            6.8             0.220         0.36            1.20      0.052
# ...

# %% [markdown]
# ## Datos distribuidos

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/distributed-data/001.csv")

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %% [markdown]
# * Importar el primer fichero
# * Hacemos un bucle para ir recorriendo todos y cada uno de los ficheros.
#     * Importante tener una consistencia en el nombre de los ficheros
#     * Importamos los ficheros uno a uno
#     * Cada uno de ellos debe apendizarse (añadirse al final) del primer fichero que ya habíamos cargado
# * Repetimos el bucle hasta que no queden ficheros

# %%
filepath = "/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/distributed-data/"
counter = 1

for i in range(2, 333):
    if i < 10:
        data_x = pd.read_csv(filepath + "00" + str(i) + ".csv")
    elif 10 <= i < 100:
        data_x = pd.read_csv(filepath + "0" + str(i) + ".csv")
    else:
        data_x = pd.read_csv(filepath + str(i) + ".csv")

    data = pd.concat([data, data_x], axis = 0)
    counter += 1

# %%
counter
# Out:
# 332

# %%
data.shape
# Out:
# (772087, 4)

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.tail()
# Out:
#            Date  sulfate  nitrate   ID
# 726  2004-12-27      NaN      NaN  332
# 727  2004-12-28      NaN      NaN  332
# 728  2004-12-29      NaN      NaN  332
# 729  2004-12-30      NaN      NaN  332
# 730  2004-12-31      NaN      NaN  332

# %% [markdown]
# # Joins de datasets

# %%
path1 = "/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/athletes/Medals.csv"

# %%
data_main = pd.read_csv(path1, encoding = "ISO-8859-1")

# %%
data_main.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
athletes_name = data_main['Athlete'].unique().tolist()
len(athletes_name)
# Out:
# 6956

# %%
data_main.shape
# Out:
# (8618, 8)

# %%
path2 = "/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/athletes/Athelete_Country_Map.csv"

# %%
data_country = pd.read_csv(path2, encoding = "ISO-8859-1")

# %%
data_country.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
len(data_country)
# Out:
# 6970

# %%
data_country[data_country['Athlete'] == "Aleksandar Ciric"]
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
path3 = "/content/drive/MyDrive/Machine Learning - Python/Datasets - Machine Learning/athletes/Athelete_Sports_Map.csv"

# %%
data_sport = pd.read_csv(path3, encoding = "ISO-8859-1")

# %%
data_sport.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
len(data_sport)
# Out:
# 6975

# %%
data_sport[(data_sport['Athlete'] == "Chen Jing") |
        (data_sport['Athlete'] == "Richard Thompson") |
        (data_sport['Athlete'] == "Matt Ryan")]
# Out:
#                Athlete         Sport
# 528   Richard Thompson     Athletics
# 1308         Chen Jing    Volleyball
# 1419         Chen Jing  Table Tennis
# 2727         Matt Ryan        Rowing
# 5003         Matt Ryan    Equestrian
# 5691  Richard Thompson      Baseball

# %%
"""
A continuación, vamos a usar el método '.merge()' para
unir data_main y data country, pero antes vamos a
eliminar los duplicados de 'Athlete' en data country,
para evidar errores en el total de medallas, por ejemplo.
"""

data_country_dp = data_country.drop_duplicates(subset = "Athlete")

# %%
# Verificando y comparando las longitudes de 'athletes_name' y 'data_country_dp'

len(data_country_dp)==len(athletes_name)
# Out:
# True

# %%
# Ahora sí procedemos con el '.merge()':

data_main_country = pd.merge(
    left = data_main,
    right = data_country_dp,
    left_on = "Athlete",
    right_on = "Athlete"
    )

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
# Vemos que tiene el mismo número de filas que data_main

data_main_country.shape
# Out:
# (8618, 9)

# %%
# Vemos nuevamente la situación de Aleksandar Ciric, por ejemplo:

data_main_country[data_main_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1491  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1492  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1493  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals Country
# 1491              0              1             1  Serbia
# 1492              1              0             1  Serbia
# 1493              0              1             1  Serbia

# %%
# Recordemos como era su situación (dos países simultáneamente):

data_country[data_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
# Igual que antes, eliminemos los duplicados del data_sport

data_sport_dp = data_sport.drop_duplicates(subset = "Athlete")

# %%
# Verificamos

len(data_sport_dp) == len(athletes_name)
# Out:
# True

# %%
data_final = pd.merge(left = data_main_country,
                      right = data_sport_dp,
                      left_on = "Athlete",
                      right_on = "Athlete")

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_sport_dp.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %%
data_final.shape
# Out:
# (8618, 10)

# %% [markdown]
# ## Tipos de Joins

# %%
from IPython.display import Image
import numpy as np

# %%
out_athletes = np.random.choice(data_main["Athlete"], size = 6, replace = False)

# %%
out_athletes
# Out:
# array(['Shawn Johnson', 'Melanie Kok', 'Dávid Tóth', 'Peter Wilson',
#        'Saori Yoshida', 'Promise Isaac'], dtype=object)

# %%
data_country_dlt = data_country_dp[(~data_country_dp["Athlete"].isin(out_athletes)) &
                                   (data_country_dp["Athlete"] != "Michael Phelps")]

data_sport_dlt = data_sport_dp[(~data_sport_dp["Athlete"].isin(out_athletes)) &
                                (data_sport_dp["Athlete"] != "Michael Phelps")]

data_main_dlt = data_main[(~data_main["Athlete"].isin(out_athletes)) &
                         (data_main["Athlete"] != "Michael Phelps")]

# %%
data_country_dlt.head()
# Out:
#             Athlete        Country
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States
# 5       Ryan Lochte  United States

# %%
data_sport_dlt.head()
# Out:
#             Athlete       Sport
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming
# 5       Ryan Lochte    Swimming

# %%
data_main_dlt.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
# 5     Alicia Coutts  24.0  2012            08/12/2012            1
# 6    Missy Franklin  17.0  2012            08/12/2012            4
# 7       Ryan Lochte  27.0  2012            08/12/2012            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 3              2              3             6
# 4              1              3             6
# 5              3              1             5
# 6              0              1             5
# 7              2              1             5

# %%
data_sport_dlt[data_sport_dlt["Athlete"] == "Michael Phelps"]
# Out:
# Empty DataFrame
# Columns: [Athlete, Sport]
# Index: []

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(data_sport_dlt)
# Out:
# 6949

# %%
len(data_main_dlt)
# Out:
# 8607

# %% [markdown]
# ### Inner Join
# * Devuelve un data frame con las filas que tienen valor tanto en el primero como en el segundo data frame que estamos uniendo
# * El número de filas será igual al número de filas **comunes** que tengas ambos data sets
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Inner Join B tendrá 30 filas
# * En términos de teoría de conjuntos, se trata de la intersección de los dos conjuntos

# %%
Image(filename = "/content/drive/MyDrive/Machine Learning - Python/resources/inner-join.png")

# %%
# data_main contiene toda la info
# data_country_dlt le falta la info de 7 atletas
merged_inner = pd.merge(left = data_main,
                        right = data_country_dlt,
                        how = "inner",
                        left_on = "Athlete",
                        right_on = "Athlete")

# %%
len(merged_inner)
# Out:
# 8607

# %%
# Notar que Michael Phelps no aparece, ya que ha sido eliminado, junto con 6 atletas más.
merged_inner.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008            08/24/2008            1
# 1  Natalie Coughlin  21.0  2004            08/29/2004            2
# 2  Natalie Coughlin  29.0  2012            08/12/2012            0
# 3     Aleksey Nemov  24.0  2000            10/01/2000            2
# 4     Alicia Coutts  24.0  2012            08/12/2012            1
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              2              3             6  United States
# 1              2              1             5  United States
# 2              0              1             1  United States
# 3              1              3             6         Russia
# 4              3              1             5      Australia

# %% [markdown]
# ### Left Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho, tendrán NAs en las columnas del data frame derecho.
# * El número de filas será igual al número de filas del data frame izquierdo
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Left Join B tendrá 60 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la izquierda quien, además tiene la intersección en su interior.

# %%
Image(filename = "/content/drive/MyDrive/Machine Learning - Python/resources/left-join.png")

# %%
merged_left = pd.merge(left = data_main, right = data_country_dlt,
                       how = "left",
                       left_on = "Athlete",
                       right_on = "Athlete")
len(merged_left)
# Out:
# 8618

# %%
"""
Fijarse que aparece Michael Phelps, pero la información respecto al país es NaN,
ya que él fue eliminado en 'data_country_dlt'
"""
merged_left.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ### Right Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la derecha, sin importar si tienen correspondencia en el de la izquierda o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame izquierdo, tendrán NAs en las columnas del data frame izquierdo.
# * El número de filas será igual al número de filas del data frame derecho
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Right Join B tendrá 50 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la derecha quien, además tiene la intersección en su interior.

# %%
Image(filename = "/content/drive/MyDrive/Machine Learning - Python/resources/right-join.png")

# %%
merged_right = pd.merge(left = data_main_dlt,
                        right = data_country_dp,
                        how = "right",
                        left_on = "Athlete",
                        right_on = "Athlete")
len(merged_right)
# Out:
# 8614

# %%
"""
Fijarse que el dataset que domina, el de la derecha, es 'data_country_dp'; aquí
habíamos eliminado los duplicados de país respecto a "Athlete". Por esta razón
aparece Michael Phelps, pero con toda la información en NaN excepto la respectiva
al país.
"""
merged_right.head(10)
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps   NaN     NaN                   NaN          NaN
# 1  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 2  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
# 3  Natalie Coughlin  29.0  2012.0            08/12/2012          0.0
# 4     Aleksey Nemov  24.0  2000.0            10/01/2000          2.0
# 5     Alicia Coutts  24.0  2012.0            08/12/2012          1.0
# 6    Missy Franklin  17.0  2012.0            08/12/2012          4.0
# 7       Ryan Lochte  27.0  2012.0            08/12/2012          2.0
# 8       Ryan Lochte  24.0  2008.0            08/24/2008          2.0
# 9       Ryan Lochte  20.0  2004.0            08/29/2004          1.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            NaN            NaN           NaN  United States
# 1            2.0            3.0           6.0  United States
# ...

# %% [markdown]
# ### Outer Join
# * Devuelve un data frame con todas las filas de ambos, reemplazando las ausencias de uno o de otro con NAs en la región específica..
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho (o izquierdo), tendrán NAs en las columnas del data frame derecho (o izquierdo).
# * El número de filas será igual al máximo número de filas de ambos data frames
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Outer Join B tendrá 60 + 50 - 30 = 80 filas
# * En términos de teoría de conjuntos, se trata de la unión de conjuntos.

# %%
Image(filename = "/content/drive/MyDrive/Machine Learning - Python/resources/outer-join.png")

# %%
data_country_jb = data_country_dlt.append({"Athlete": "Juan Gabriel Gomila",
                                           "Country": "España"},
                                           ignore_index = True)
# Out:
# <ipython-input-84-d2a736b031f0>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_country_jb = data_country_dlt.append({"Athlete": "Juan Gabriel Gomila",

# %%
merged_outer = pd.merge(left = data_main,
                        right = data_country_jb,
                        how = "outer",
                        left_on = "Athlete",
                        right_on="Athlete")
len(merged_outer)
# Out:
# 8619

# %%
merged_outer.tail()
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8614      Kateryna Serdiuk  17.0  2000.0            10/01/2000          0.0
# 8615      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8616  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8617             Rod White  23.0  2000.0            10/01/2000          0.0
# 8618   Juan Gabriel Gomila   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8614            1.0            0.0           1.0        Ukraine
# 8615            0.0            1.0           1.0    Netherlands
# 8616            0.0            1.0           1.0        Germany
# 8617            0.0            1.0           1.0  United States
# 8618            NaN            NaN           NaN         España

# %%
len(data_main)
# Out:
# 8618

# %%
len(data_main_dlt)
# Out:
# 8607

# %%
len(data_country_dp)
# Out:
# 6956

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(merged_inner)
# Out:
# 8607

# %%
len(merged_left)
# Out:
# 8618

# %%
len(merged_right)
# Out:
# 8614

# %%
len(merged_outer)
# Out:
# 8619
