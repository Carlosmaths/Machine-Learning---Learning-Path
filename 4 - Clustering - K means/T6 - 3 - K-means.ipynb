# %% [markdown]
# # El Método de K-Means

# %%
import numpy as np

# %%
data = np.random.random(90).reshape(30, 3)
data
# Out:
# array([[0.57113373, 0.08493786, 0.97489688],
#        [0.16713099, 0.0514821 , 0.34620206],
#        [0.84567997, 0.82478229, 0.71322657],
#        [0.59204461, 0.0386171 , 0.42303071],
#        [0.34367939, 0.59822644, 0.92357738],
#        [0.32201714, 0.63722053, 0.37103049],
#        [0.24082072, 0.66429606, 0.24685429],
#        [0.07577432, 0.924124  , 0.40731005],
#        [0.3821555 , 0.97396829, 0.00218387],
#        [0.4859924 , 0.16767526, 0.34070665],
#        [0.16602257, 0.06387187, 0.86077736],
#        [0.7915238 , 0.20199202, 0.74741395],
#        [0.16301138, 0.15258002, 0.65603834],
#        [0.28243235, 0.82661399, 0.5271491 ],
#        [0.56232911, 0.10566921, 0.49194924],
#        [0.40248906, 0.73709188, 0.14923175],
#        [0.16867236, 0.42492398, 0.34332415],
#        [0.02278279, 0.42794379, 0.65895465],
#        [0.4002783 , 0.00926545, 0.46297724],
#        [0.2078459 , 0.83824318, 0.96485232],
#        [0.9477764 , 0.09052379, 0.86504616],
#        [0.76629479, 0.43852732, 0.28113784],
#        [0.31337994, 0.81069146, 0.67374631],
#        [0.56948272, 0.62990847, 0.45009814],
#        [0.06684905, 0.99024245, 0.06565606],
#        [0.40552653, 0.58074872, 0.74210003],
#        [0.99845399, 0.00737155, 0.02847988],
#        [0.04492157, 0.73263235, 0.84128179],
#        [0.15403085, 0.15057531, 0.2112034 ],
#        [0.26419615, 0.79390792, 0.70393817]])

# %%
data[0]
# Out:
# array([0.57113373, 0.08493786, 0.97489688])

# %%
c1 = np.random.choice(range(len(data)))
c2 = np.random.choice(range(len(data)))

# %%
c1, c2
# Out:
# (9, 13)

# %%
clust_centers = np.vstack([data[c1], data[c2]])

# %%
clust_centers
# Out:
# array([[0.4859924 , 0.16767526, 0.34070665],
#        [0.28243235, 0.82661399, 0.5271491 ]])
